# %%
creatVars = locals()
def coverttime(df):
    df.TRADE_TYPE[df.TRADE_TYPE==21] = 1
    df.TRADE_TYPE[df.TRADE_TYPE==22] = 0
    df['time'] = df.START_DATE.apply(lambda x:x[:19])
    df['time'] = pd.to_datetime(df['time'],format='%Y-%m-%d-%H.%M.%S')
    df['week'] = df['time'].dt.dayofweek+1
    timedelta = df['time'] - pd.datetime(df['time'].dt.year[0],df['time'].dt.month[0],df['time'].dt.day[0],0,0,0)
    df['minstep'] = timedelta.dt.seconds/3600
    df['minstep'] = df['minstep'].astype(int)
    return df

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings('ignore')

# %%
import pandas as pd
pd.options.display.max_columns = None

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus']=False
import pandas as pd
def pltinoutsta(df,plot=True):
    #统计每一小时，进出站的人数
    insta=[]
    outsta=[]
    minsteps=df['minstep'].unique()
    for minstep in minsteps:
        insta.append((df[df['minstep']==minstep]['TRADE_TYPE']==1).sum())
        outsta.append((df[df['minstep']==minstep]['TRADE_TYPE']==0).sum())
    if plot==True:
        plt.plot(minstep,insta,color='red',label='insta')
        plt.plot(minstep,outsta,color='green',label='outsta')
        plt.show()
    else:
        pass
    return minsteps,insta,outsta

# %%
path = '../dataofweek/'

# %%
data12 = pd.read_csv(path+'12_week.csv')
data12= coverttime(data12)

# %%
data13 = pd.read_csv(path+'13_week.csv')

# %%
data13 = coverttime(data13)

# %%
data14 = pd.read_csv(path+'14_week.csv')

# %%
data14 = coverttime(data14)

# %%
data15 = pd.read_csv(path+'15_week.csv')

# %%
data15 = coverttime(data15)

# %%
data16 = pd.read_csv(path+'16_week.csv')

# %%
data16 = coverttime(data16)

# %%
data17 = pd.read_csv(path+'17_week.csv')

# %%
data17 = coverttime(data17)

# %%
# #9.8-14
# fig = plt.figure(figsize=(30,15))
# df6 = data6[(data6.week!= 6)&(data6.week!= 7)&(data6.week!= 1)&(data6.week!= 5)]
# for i in list(df6.week.unique()):
    
#     data = df6[df6.week==i]
    
#     minsteps,instas,outstas = pltinoutsta(data,plot=False)
#     plt.plot(minsteps, instas, label=i)

# plt.title('第六周入站流量统计', fontsize=30)
# legend=plt.legend(title='days', fontsize=30)
# legend.get_title().set_fontsize(fontsize=30)

# plt.tick_params(labelsize=30)
# plt.xlabel('每一小时',size=30)
# plt.ylabel('流量',size=30)
# plt.savefig('6_week.png')
# plt.show()

# %%
# #9.15-21
# fig = plt.figure(figsize=(30,15))

# df7 = data7[(data7.week!= 6)&(data7.week!= 7)&(data7.week!= 1)&(data7.week!= 5)&(data7.week!= 2)]

# for i in list(df7.week.unique()):
    
#     data = df7[df7.week==i]
    
#     minsteps,instas,outstas = pltinoutsta(data,plot=False)
#     plt.plot(minsteps, instas, label=i)

# plt.title('第七周入站流量统计', fontsize=30)
# legend=plt.legend(title='days', fontsize=30)
# legend.get_title().set_fontsize(fontsize=30)

# plt.tick_params(labelsize=30)
# plt.xlabel('每一小时',size=30)
# plt.ylabel('流量',size=30)
# plt.savefig('7_week.png')
# plt.show()

# %%
# #9.22-28
# fig = plt.figure(figsize=(30,15))


# df8 = data8[(data8.week!= 6)&(data8.week!= 7)&(data8.week!= 5)&(data8.week!= 2)&(data8.week!= 1)]

# for i in list(df8.week.unique()):
    
#     data = df8[df8.week==i]
    
#     minsteps,instas,outstas = pltinoutsta(data,plot=False)
#     plt.plot(minsteps, instas, label=i)

# plt.title('第八周入站流量统计', fontsize=30)
# legend=plt.legend(title='days', fontsize=30)
# legend.get_title().set_fontsize(fontsize=30)

# plt.tick_params(labelsize=30)
# plt.xlabel('每一小时',size=30)
# plt.ylabel('流量',size=30)
# plt.savefig('8_week.png')
# plt.show()

# %%
# #10.13-10-19
# fig = plt.figure(figsize=(30,15))


# df8 = data11[(data11.week!= 6)&(data11.week!= 7)&(data11.week!= 5)&(data11.week!= 1)&(data11.week!= 4)]

# for i in list(df8.week.unique()):
    
#     data = df8[df8.week==i]
    
#     minsteps,instas,outstas = pltinoutsta(data,plot=False)
#     plt.plot(minsteps, instas, label=i)

# plt.title('第十一周入站流量统计', fontsize=30)
# legend=plt.legend(title='days', fontsize=30)
# legend.get_title().set_fontsize(fontsize=30)

# plt.tick_params(labelsize=30)
# plt.xlabel('每一小时',size=30)
# plt.ylabel('流量',size=30)
# plt.savefig('8_week.png')
# plt.show()

# %%
#10.20-10.26
fig = plt.figure(figsize=(30,15))

# df12 = data12[(data12.week!= 6)&(data12.week!= 7)]

df12 = data12

for i in list(df12.week.unique()):
    
    data = df12[df12.week==i]
    
    minsteps,instas,outstas = pltinoutsta(data,plot=False)
    plt.plot(minsteps, instas, label=i)

plt.title('第十二周入站流量统计（10.20-26）', fontsize=30)
legend=plt.legend(title='days', fontsize=30)
legend.get_title().set_fontsize(fontsize=30)

plt.tick_params(labelsize=30)
plt.xlabel('每一小时',size=30)
plt.ylabel('流量',size=30)
plt.savefig('./pic/12_week_in.png')
plt.show()

# %%
#10.27-11.2
fig = plt.figure(figsize=(30,15))


# df13 = data13[(data13.week!= 6)&(data13.week!= 7)]
df13 = data13



for i in list(df13.week.unique()):
    
    data = df13[df13.week==i]
    
    minsteps,instas,outstas = pltinoutsta(data,plot=False)
    plt.plot(minsteps, instas, label=i)

plt.title('第十三周入站流量统计（10.27-11.2）', fontsize=30)
legend=plt.legend(title='days', fontsize=30)
legend.get_title().set_fontsize(fontsize=30)

plt.tick_params(labelsize=30)
plt.xlabel('每一小时',size=30)
plt.ylabel('流量',size=30)
plt.savefig('./pic/13_week_in.png')
plt.show()

# %%
#11.3-11.9
fig = plt.figure(figsize=(30,15))


# df14 = data14[(data14.week!= 6)&(data14.week!= 7)]

df14 = data14


for i in list(df14.week.unique()):
    
    data = df14[df14.week==i]
    
    minsteps,instas,outstas = pltinoutsta(data,plot=False)
    plt.plot(minsteps, instas, label=i)

plt.title('第十四周入站流量统计（11.3-9）', fontsize=30)
legend=plt.legend(title='days', fontsize=30)
legend.get_title().set_fontsize(fontsize=30)

plt.tick_params(labelsize=30)
plt.xlabel('每一小时',size=30)
plt.ylabel('流量',size=30)
plt.savefig('./pic/14_week_in.png')
plt.show()

# %%
#11.10-11.16
fig = plt.figure(figsize=(30,15))


# df15 = data15[(data15.week!= 6)&(data15.week!= 7)&(data15.week!= 5)]

df15 = data15

for i in list(df15.week.unique()):
    
    data = df15[df15.week==i]
    
    minsteps,instas,outstas = pltinoutsta(data,plot=False)
    plt.plot(minsteps, instas, label=i)

plt.title('第十五周入站流量统计（11.10-11.16）', fontsize=30)
legend=plt.legend(title='days', fontsize=30)
legend.get_title().set_fontsize(fontsize=30)

plt.tick_params(labelsize=30)
plt.xlabel('每一小时',size=30)
plt.ylabel('流量',size=30)
plt.savefig('./pic/14_week_in.png')
plt.show()

# %%
#11.17-23
fig = plt.figure(figsize=(30,15))
# df16 = data16[(data16.week!= 6)&(data16.week!= 7)&(data16.week!= 5)]

df16 = data16


for i in list(df16.week.unique()):
    
    data = df16[df16.week==i]
    
    minsteps,instas,outstas = pltinoutsta(data,plot=False)
    plt.plot(minsteps, instas, label=i)

plt.title('第十六周入站流量统计（11.17-11.23）', fontsize=30)
legend=plt.legend(title='days', fontsize=30)
legend.get_title().set_fontsize(fontsize=30)

plt.tick_params(labelsize=30)
plt.xlabel('每一小时',size=30)
plt.ylabel('流量',size=30)
plt.savefig('./pic/16_week_in.png')
plt.show()

# %%
#11.17-23
fig = plt.figure(figsize=(30,15))
df17 = data17[(data17.week!= 6)&(data17.week!= 7)&(data17.week!= 5)]

for i in list(df17.week.unique()):
    
    data = df17[df17.week==i]
    minsteps,instas,outstas = pltinoutsta(data,plot=False)
    plt.plot(minsteps, instas, label=i)

plt.title('第十七周入站流量统计', fontsize=30)
legend=plt.legend(title='days', fontsize=30)
legend.get_title().set_fontsize(fontsize=30)

plt.tick_params(labelsize=30)
plt.xlabel('每一小时',size=30)
plt.ylabel('流量',size=30)
plt.savefig('./pic/17_week_in.png')
plt.show()
