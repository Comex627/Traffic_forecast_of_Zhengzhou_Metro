# %%
creatVars = locals()
def coverttime(df):
    df.TRADE_TYPE[df.TRADE_TYPE==21] = 1
    df.TRADE_TYPE[df.TRADE_TYPE==22] = 0
    df['time'] = df.START_DATE.apply(lambda x:x[:19])
    df['time'] = pd.to_datetime(df['time'],format='%Y-%m-%d-%H.%M.%S')
    df['week'] = df['time'].dt.dayofweek+1
    timedelta = df['time'] - pd.datetime(df['time'].dt.year[0],df['time'].dt.month[0],df['time'].dt.day[0],0,0,0)
    df['minstep'] = timedelta.dt.seconds/3600
    df['minstep'] = df['minstep'].astype(int)
    return df

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings('ignore')

# %%
import pandas as pd
pd.options.display.max_columns = None

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus']=False
import pandas as pd
def pltinoutsta(df,plot=True):
    #统计每一个十分钟时间段，进出站的人数
    insta=[]
    outsta=[]
    minsteps=df['minstep'].unique()
    for minstep in minsteps:
        insta.append((df[df['minstep']==minstep]['TRADE_TYPE']==1).sum())
        outsta.append((df[df['minstep']==minstep]['TRADE_TYPE']==0).sum())
    if plot==True:
        plt.plot(minstep,insta,color='red',label='insta')
        plt.plot(minstep,outsta,color='green',label='outsta')
        plt.show()
    else:
        pass
    return minsteps,insta,outsta

# %%
path = '../dataofweek/'

# %%
data12 = pd.read_csv(path+'12_week.csv')

# %%
data12= coverttime(data12)

# %%
data13 = pd.read_csv(path+'13_week.csv')

# %%
data13 = coverttime(data13)

# %%
data14 = pd.read_csv(path+'14_week.csv')

# %%
data14 = coverttime(data14)

# %%
data16 = pd.read_csv(path+'16_week.csv')

# %%
data16 = coverttime(data16)

# %%
#10.20-26
fig = plt.figure(figsize=(30,15))
data12 = coverttime(data12)

data12 = data12[(data12.week!= 1)&(data12.week!= 5)&(data12.week!= 6)&(data12.week!= 7)]

for i in list(data12.week.unique()):
    
    data = data12[data12.week==i]
    
    minsteps,instas,outstas = pltinoutsta(data,plot=False)
    plt.plot(minsteps, outstas, label=i)

plt.title('第十二周入站流量统计', fontsize=30)
legend=plt.legend(title='days', fontsize=30)
legend.get_title().set_fontsize(fontsize=30)

plt.tick_params(labelsize=30)
plt.xlabel('每一小时',size=30)
plt.ylabel('流量',size=30)
plt.savefig('./pic/12_week_out.png')
plt.show()

# %%
#10.27-11.2
fig = plt.figure(figsize=(30,15))

data13 = coverttime(data13)

data13 = data13[(data13.week!= 1)&(data13.week!= 5)&(data13.week!= 6)&(data13.week!= 7)]

# #数据矫正

# #10.21
# data12_3 = data12[data12.week==3]
# #10.28
# data12_3.date = data12_3.date.apply(lambda x:x.replace('21','28'))

# data13_2 = data13[data13.week==2]
# data13_4 = data13[data13.week==4]
# data13 = pd.concat([data13_2,data12_3],axis=0,ignore_index=True)
# data13 = pd.concat([data13,data13_4],axis=0,ignore_index=True)

# del data12_3,data13_2,data13_4

for i in list(data13.week.unique()):
    
    data = data13[data13.week==i]
    
    minsteps,instas,outstas = pltinoutsta(data,plot=False)
    plt.plot(minsteps, outstas, label=i)

plt.title('第十三周入站流量统计', fontsize=30)
legend=plt.legend(title='days', fontsize=30)
legend.get_title().set_fontsize(fontsize=30)

plt.tick_params(labelsize=30)
plt.xlabel('每一小时',size=30)
plt.ylabel('流量',size=30)
plt.savefig('./pic/13_week_out.png')
plt.show()

# %%
#11.3-9
fig = plt.figure(figsize=(30,15))


data14 = data14[(data14.week!= 1)&(data14.week!= 5)&(data14.week!= 6)&(data14.week!= 7)]


for i in list(data14.week.unique()):
    
    data = data14[data14.week==i]
    
    minsteps,instas,outstas = pltinoutsta(data,plot=False)
    plt.plot(minsteps, outstas, label=i)

plt.title('第十四周入站流量统计', fontsize=30)
legend=plt.legend(title='days', fontsize=30)
legend.get_title().set_fontsize(fontsize=30)

plt.tick_params(labelsize=30)
plt.xlabel('每一小时',size=30)
plt.ylabel('流量',size=30)
plt.savefig('./pic/14_week_out.png')
plt.show()

# %%
#11.17-23
fig = plt.figure(figsize=(30,15))
data16 = data16[(data16.week!= 1)&(data16.week!= 5)&(data16.week!= 6)&(data16.week!= 7)]

# #数据矫正/周三
# #11.4
# data14_3 = data14[data14.week==3]

# data14_3.date = data14_3.date.apply(lambda x:x.replace('2015-11-04','2015-11-18'))

# data16_2 = data16[data16.week==2]
# data16_4 = data16[data16.week==4]

# data16 = pd.concat([data16_2,data14_3],axis=0,ignore_index=True)
# data16 = pd.concat([data16,data16_4],axis=0,ignore_index=True)
# #数据矫正/周四
# data14_4 = data14[data14.week==4]
# data14_4.date = data14_4.date.apply(lambda x:x.replace('2015-11-05','2015-11-19'))
                                                       
# data16_2_3 = data16[data16.week!=4]
# data16 = pd.concat([data16_2_3,data14_4],axis=0,ignore_index=True)

# del data14_3,data16_2,data16_4,data14_4

for i in list(data16.week.unique()):
    
    data = data16[data16.week==i]
    
    minsteps,instas,outstas = pltinoutsta(data,plot=False)
    plt.plot(minsteps, outstas, label=i)

plt.title('第十六周入站流量统计', fontsize=30)
legend=plt.legend(title='days', fontsize=30)
legend.get_title().set_fontsize(fontsize=30)

plt.tick_params(labelsize=30)
plt.xlabel('每一小时',size=30)
plt.ylabel('流量',size=30)
plt.savefig('./pic/16_week_out.png')
plt.show()
